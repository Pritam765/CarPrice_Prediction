# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\ptt920460\Downloads\car data.csv")
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.shape
# Out:
# (301, 9)

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=data)
# Out:
# <AxesSubplot:>

# %%
np.max(data.Year)
# Out:
# 2018

# %%
#converting year to the age of the car:


Age=2023 - data.Year

data.insert(0, 'Age', Age)

data.drop('Year',  axis=1, inplace=True)

# %%
data
# Out:
#      Age Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      9     ritz           3.35           5.59       27000    Petrol
# 1     10      sx4           4.75           9.54       43000    Diesel
# 2      6     ciaz           7.25           9.85        6900    Petrol
# 3     12  wagon r           2.85           4.15        5200    Petrol
# 4      9    swift           4.60           6.87       42450    Diesel
# ..   ...      ...            ...            ...         ...       ...
# 296    7     city           9.50          11.60       33988    Diesel
# 297    8     brio           4.00           5.90       60000    Petrol
# 298   14     city           3.35          11.00       87934    Petrol
# 299    6     city          11.50          12.50        9000    Diesel
# 300    7     brio           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
data.corr()
# Out:
#                     Age  Selling_Price  Present_Price  Kms_Driven     Owner
# Age            1.000000      -0.236141       0.047584    0.524342  0.182104
# Selling_Price -0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price  0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven     0.524342       0.029187       0.203647    1.000000  0.089216
# Owner          0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
features= ['Selling_Price', 'Present_Price', 'Kms_Driven']

# %%
new_data=pd.DataFrame(data, columns=features +['Age'])
new_data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Age
# 0             3.35           5.59       27000    9
# 1             4.75           9.54       43000   10
# 2             7.25           9.85        6900    6
# 3             2.85           4.15        5200   12
# 4             4.60           6.87       42450    9
# ..             ...            ...         ...  ...
# 296           9.50          11.60       33988    7
# 297           4.00           5.90       60000    8
# 298           3.35          11.00       87934   14
# 299          11.50          12.50        9000    6
# 300           5.30           5.90        5464    7
#
# [301 rows x 4 columns]

# %%
new_data=new_data.set_index('Age')
new_data
# Out:
#      Selling_Price  Present_Price  Kms_Driven
# Age
# 9             3.35           5.59       27000
# 10            4.75           9.54       43000
# 6             7.25           9.85        6900
# 12            2.85           4.15        5200
# 9             4.60           6.87       42450
# ..             ...            ...         ...
# 7             9.50          11.60       33988
# 8             4.00           5.90       60000
# 14            3.35          11.00       87934
# 6            11.50          12.50        9000
# 7             5.30           5.90        5464
#
# [301 rows x 3 columns]

# %%
X = pd.DataFrame(data, columns = ['Age','Present_Price', 'Kms_Driven'])
y = data['Selling_Price'].values.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
# MAE
print("Mean Absolute Error: ", mean_absolute_error(Y_test, Y_pred))
# Out:
# Mean Absolute Error:  1.2085335799254895

# %%
# MSE
print("Mean Squared Error: ", mean_squared_error(Y_test, Y_pred))
# Out:
# Mean Squared Error:  2.845062142450955

# %%
#RMSE
print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# Root Mean Squared Error:  1.6867312004142672

# %%
#R2 Score
print("R2 Score: ", r2_score(Y_test,Y_pred))
# Out:
# R2 Score:  0.887446046362037

# %%
Accuracy = ("The accuracy of model is :", r2_score(Y_test, Y_pred)*100)
Accuracy
# Out:
# ('The accuracy of model is :', 88.7446046362037)
